# %%
import model
# Out:
# Using TensorFlow backend.

# %%
relation = [0]*274
n_svd = 300

# %%
model.CNN(maxlen=450, torel=relation, 
          dense_layers=[200, 100], drop_dense=0.3, 
          residue=True, drop_res=0.5, 
          filter=100, drop_emb=0.7, feature=n_svd).plot('img/henry-plus.png')
